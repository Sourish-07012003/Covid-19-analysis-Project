# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\souri\AppData\Local\Temp\adef43ce-2a63-455d-b609-49a4f16034b9_archive.zip.4b9\country_wise_latest.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            10             18                3.50                  69.49
# 1             6             63                2.95                  56.25
# 2             8            749                4.16                  67.34
# 3             0              0                5.73                  88.53
# 4             1              0                4.32                  25.47
# ..          ...            ...                 ...                    ...
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                      5.04                35526            737
# 1                      5.25                 4171            709
# 2                      6.17                23691           4282
# 3                      6.48                  884             23
# 4                     16.94                  749            201
# ..                      ...                  ...            ...
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO Region
# 0                 2.07  Eastern Mediterranean
# 1                17.00                 Europe
# 2                18.07                 Africa
# 3                 2.60                 Europe
# 4                26.84                 Africa
# ..                 ...                    ...
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa
#
# [187 rows x 15 columns]>

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
data.tail()
# Out:
#            date state  death  deathConfirmed  deathIncrease  deathProbable  \
# 366  2020-03-06    NY    NaN             NaN              0            NaN
# 367  2020-03-05    NY    NaN             NaN              0            NaN
# 368  2020-03-04    NY    NaN             0.0              0            NaN
# 369  2020-03-03    NY    NaN             NaN              0            NaN
# 370  2020-03-02    NY    NaN             NaN              0            NaN
#
#      hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 366           NaN                     NaN                    NaN
# 367           NaN                     NaN                    NaN
# 368           NaN                     NaN                    NaN
# 369           NaN                     NaN                    NaN
# 370           NaN                     NaN                    NaN
#
#      hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 366                     0  ...               122                        92
# 367                     0  ...                30                        20
# 368                     0  ...                10                         9
# 369                     0  ...                 1                         1
# 370                     0  ...                 0                         0
#
#      totalTestsAntibody  totalTestsAntigen  totalTestsPeopleAntibody  \
# 366                 NaN                NaN                       NaN
# 367                 NaN                NaN                       NaN
# 368                 NaN                NaN                       NaN
# 369                 NaN                NaN                       NaN
# 370                 NaN                NaN                       NaN
#
#      totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 366                      NaN                    NaN
# 367                      NaN                    NaN
# 368                      NaN                    NaN
# 369                      NaN                    NaN
# 370                      NaN                    NaN
#
#      totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 366                              0              NaN                        0
# 367                              0              NaN                        0
# 368                              0              NaN                        0
# 369                              0              NaN                        0
# 370                              0              NaN                        0
#
# [5 rows x 41 columns]

# %%
data.describe()
# Out:
#               death  deathConfirmed  deathIncrease  deathProbable  \
# count    358.000000             1.0     371.000000            0.0
# mean   24733.148045             0.0     105.199461            NaN
# std     8387.230568             NaN     163.273185            NaN
# min        3.000000             0.0       0.000000            NaN
# 25%    24503.000000             0.0       8.000000            NaN
# 50%    25373.500000             0.0      37.000000            NaN
# 75%    27288.250000             0.0     135.500000            NaN
# max    39029.000000             0.0     951.000000            NaN
#
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# count           0.0                     0.0             356.000000
# mean            NaN                     NaN            4534.373596
# std             NaN                     NaN            4609.351448
# min             NaN                     NaN             325.000000
# 25%             NaN                     NaN             797.250000
# 50%             NaN                     NaN            2726.000000
# 75%             NaN                     NaN            7278.500000
# max             NaN                     NaN           18825.000000
#
#        hospitalizedIncrease  inIcuCumulative  inIcuCurrently  ...  \
# count                 371.0              0.0      347.000000  ...
# mean                    0.0              NaN     1105.890490  ...
# std                     0.0              NaN     1280.901913  ...
# min                     0.0              NaN      109.000000  ...
# 25%                     0.0              NaN      172.000000  ...
# 50%                     0.0              NaN      667.000000  ...
# 75%                     0.0              NaN     1445.000000  ...
# max                     0.0              NaN     5225.000000  ...
#
#        totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# count      3.710000e+02                371.000000                 0.0
# mean       1.226413e+07             106994.878706                 NaN
# std        1.160051e+07              77228.363768                 NaN
# min        0.000000e+00                  0.000000                 NaN
# 25%        2.198652e+06              51206.000000                 NaN
# 50%        8.517458e+06              82009.000000                 NaN
# 75%        2.028116e+07             161741.500000                 NaN
# max        3.969510e+07             324671.000000                 NaN
#
#        totalTestsAntigen  totalTestsPeopleAntibody  totalTestsPeopleAntigen  \
# count                0.0                       0.0                      0.0
# mean                 NaN                       NaN                      NaN
# std                  NaN                       NaN                      NaN
# min                  NaN                       NaN                      NaN
# 25%                  NaN                       NaN                      NaN
# 50%                  NaN                       NaN                      NaN
# 75%                  NaN                       NaN                      NaN
# max                  NaN                       NaN                      NaN
#
#        totalTestsPeopleViral  totalTestsPeopleViralIncrease  totalTestsViral  \
# count                    0.0                          371.0              0.0
# mean                     NaN                            0.0              NaN
# std                      NaN                            0.0              NaN
# min                      NaN                            0.0              NaN
# 25%                      NaN                            0.0              NaN
# 50%                      NaN                            0.0              NaN
# 75%                      NaN                            0.0              NaN
# max                      NaN                            0.0              NaN
#
#        totalTestsViralIncrease
# count                    371.0
# mean                       0.0
# std                        0.0
# min                        0.0
# 25%                        0.0
# 50%                        0.0
# 75%                        0.0
# max                        0.0
#
# [8 rows x 39 columns]

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.relplot(x="Active",y="Confirmed",hue='New cases',data=data)
# Out:
# C:\Users\souri\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
sns.catplot(x="Active",y="Confirmed",data=data)
# Out:
# C:\Users\souri\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
